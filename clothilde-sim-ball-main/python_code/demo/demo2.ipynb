# %% [markdown]
# ### Import packages needed

# %%
import sys,os
notebook_dir = os.getcwd()  
parent_dir = os.path.abspath(os.path.join(notebook_dir, '..'))
sys.path.append(parent_dir)
from implementation.Cloth import Cloth 
from implementation.utils import createRectangularMesh
import time
import numpy as np

# %% [markdown]
# ### Create or load an initial mesh

# %%
na = 25; nb = 25
X, T = createRectangularMesh(a = 1,b = 1, na = na, nb = nb, h = 0.125)
X[:,2] += .65; #adjust height

# %% [markdown]
# ### Call the Cloth class

# %%
clothilde = Cloth(X, T); #clothilde.plotMesh()

# %% [markdown]
# ### Set simulator parameters:

# %%
# solver parameters
dt = 1/60 #time step
tol = 0.0075 # up to 0.75% of relative error in constraint satisfaction to stop iterations

#physical parameters
rho = 0.1 #cloth density
delta = 0.1 # aerodynamics parameter: between 0 and rho
kappa = 0.5*1e-4 # stifness or bending resistance
kappa_bnd = 0.05*1e-4 # stifness or bending resistance of the boudnary curves
alpha = 0.2 #damping of oscillations
shr = 2.5*1e-4 #allowed shearing resistance
str = 0.005*1e-4 #allowed stretching resistance
mu_f = 0.7 #friction with the floor
mu_s = 0.35 #friction with the cloth itself
thck = 0.9 #size of the balls

clothilde.setSimulatorParameters(dt=dt,tol=tol,
                                rho=rho,delta=delta,kappa=kappa,kappa_bnd=kappa_bnd,shr=shr,
                                str=str,alpha=alpha,mu_f=mu_f,mu_s=mu_s,
                                thck=thck)

# %% [markdown]
# ### Let's simulate!

# %%
clothilde.restart()

# %%
inds_ctr = [0,na-1]; tf = int(2/dt)
start_time = time.time()
for i in range(tf):
    clothilde.simulate(u = clothilde.positions[inds_ctr], control = inds_ctr)
print('Time:',time.time()-start_time)
print('Average iterations',clothilde.total_iters/(len(clothilde.history_pos)-1))
# Out:
# Time: 0.8878335952758789
# Average iterations 1.0075

# %%
clothilde.makeMovie(1,True,2)
# Out:
# [polyscope] Backend: openGL3_glfw -- Loaded openGL version: 3.3.0 NVIDIA 590.48.01

# %% [markdown]
# ### Let's stretch up things a little bit

# %%
tf = int(1/dt); t = np.linspace(0,2*np.pi,tf);

# %%
inds_ctr = [0,na-1]
u = clothilde.positions[inds_ctr]; 
for i in range(tf):
    u[0] -= np.array([0.0025*np.sin(t[i]),0,0])
    clothilde.simulate(u = u, control = inds_ctr)

# %%
clothilde.makeMovie(1,True,2)

# %% [markdown]
# ### And up again

# %%
t = np.linspace(0,np.pi,tf);

# %%
inds_ctr = [0,na-1]; freq = 3
u = clothilde.positions[inds_ctr]; 
for i in range(tf):
    u[:,2] += 0.01 #*np.sin(freq*t[i])
    clothilde.simulate(u = u, control = inds_ctr)

# %%
inds_ctr = []; tf = int(3/dt);
u = clothilde.positions[inds_ctr]; 
for i in range(tf):
    clothilde.simulate(u = u, control = inds_ctr)

# %%
clothilde.makeMovie(1,True,2)

# %% [markdown]
# ### And a final surprise

# %%
na = 21; nb = 22
X, T = createRectangularMesh(a = 1,b = 1.4, na = na, nb = nb, h = 0.4)
X[:,2] += 0.9; #adjust height
Y = X.copy(); 
Y[:,1] += 0.75
Y[:,2] -= 0.25
Z = Y.copy()
Z[:,0] += 0.75
Z[:,2] -= 0.15
X = np.concatenate([X,Y,Z]); T = np.concatenate([T,T+na*nb,T+2*na*nb])

# %%
clothilde = Cloth(X, T); 
clothilde.setSimulatorParameters(dt=1/60,tol=tol,
                                rho=rho,delta=delta,kappa=kappa,shr=shr,
                                str=str,alpha=alpha,mu_f=mu_f,mu_s=mu_s,
                                thck=thck)
clothilde.plotMesh()

# %%
inds_ctr = [na-1,na*nb +na-1, na*nb + na*nb-1]
u = clothilde.positions[inds_ctr]; 
for i in range(tf):
    clothilde.simulate(u = u, control = inds_ctr)

# %%
clothilde.makeMovie(1,True,2)

# %%
print('Average iterations',clothilde.total_iters/(len(clothilde.history_pos)-1))
# Out:
# Average iterations 1.0116666666666667
